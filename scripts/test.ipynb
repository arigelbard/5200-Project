# %%
test = {
    1:   'Corn',
    176: 'Grassland/Pasture',
    190: 'Woody Wetlands',
    195: 'Herbaceous Wetlands',
}

# %%
test[1]
# Out:
# 'Corn'

# %%
CORN              = 1
GRASSLAND         = 176
WOODY_WETLAND     = 190
HERB_WETLAND      = 195
NATURAL_CODES     = {GRASSLAND, WOODY_WETLAND, HERB_WETLAND}

NATURAL_CODES
# Out:
# {176, 190, 195}
